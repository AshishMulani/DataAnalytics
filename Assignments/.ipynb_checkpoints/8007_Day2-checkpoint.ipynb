# %% [markdown]
# ## Pandas Basics (1–20)

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#1. Load the Titanic dataset into a DataFrame.
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
#2. Display the first 10 rows.
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# 6    man        True    E  Southampton    no   True
# 7  child       False  NaN  Southampton    no  False
# 8  woman       False  NaN  Southampton   yes  False
# 9  child       False  NaN    Cherbourg   yes  False

# %%
#3. Display the last 5 rows.
df.tail(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
#4. Find the number of rows and columns.
rows=df.shape[0]
col=df.shape[1]
print("Rows: ",rows)
print("Columns: ",col)
# Out:
# Rows:  891
# Columns:  15

# %%
#5. Display all column names.
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='str')

# %%
#6. Check data types of each column.
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex                 str
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked            str
# class          category
# who                 str
# adult_male         bool
# deck           category
# embark_town         str
# alive               str
# alone              bool
# dtype: object

# %%
#7. Find total number of missing values in each column.
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#8. Display summary statistics of numerical columns.
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#9. Display summary statistics of all columns.
df.describe(include='all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# count   891.000000      889    891  891        891  203          889   891
# unique         NaN        3      3    3          2    7            3     2
# top            NaN        S  Third  man       True    C  Southampton    no
# freq           NaN      644    491  537        537   59          644   549
# mean     32.204208      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# std      49.693429      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# min       0.000000      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 25%       7.910400      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 50%      14.454200      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 75%      31.000000      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# max     512.329200      NaN    NaN  NaN        NaN  NaN          NaN   NaN
#
#        alone
# count    891
# unique     2
# top     True
# freq     537
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN

# %%
#10. Select only `Name`, `Age`, and `Fare`.
df[["age","fare"]]
# Out:
#       age     fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
#11. Display passengers older than 30.
df[df["age"]>30]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 873         0       3    male  47.0      0      0   9.0000        S  Third
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 881         0       3    male  33.0      0      0   7.8958        S  Third
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# 6      man        True    E  Southampton    no   True
# 11   woman       False    C  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 873    man        True  NaN  Southampton    no   True
# 879  woman       False    C    Cherbourg   yes  False
# 881    man        True  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 890    man        True  NaN   Queenstown    no   True
#
# [305 rows x 15 columns]

# %%
#12. Display female passengers only.
df[df["sex"]=="female"]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 8    woman       False  NaN  Southampton   yes  False
# 9    child       False  NaN    Cherbourg   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 880  woman       False  NaN  Southampton   yes  False
# 882  woman       False  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
#
# [314 rows x 15 columns]

# %%
#13. Display passengers from class 1.
df[df["class"]=="First"]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 11          1       1  female  58.0      0      0  26.5500        S  First
# 23          1       1    male  28.0      0      0  35.5000        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 3    woman       False    C  Southampton   yes  False
# 6      man        True    E  Southampton    no   True
# 11   woman       False    C  Southampton   yes   True
# 23     man        True    A  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 871  woman       False    D  Southampton   yes  False
# 872    man        True    B  Southampton    no   True
# 879  woman       False    C    Cherbourg   yes  False
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [216 rows x 15 columns]

# %%
#14. Display passengers whose fare is greater than 50.
df[df["fare"]>50]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1           1       1  female  38.0      1      0   71.2833        C  First
# 3           1       1  female  35.0      1      0   53.1000        S  First
# 6           0       1    male  54.0      0      0   51.8625        S  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
# 31          1       1  female   NaN      1      0  146.5208        C  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 856         1       1  female  45.0      1      1  164.8667        S  First
# 863         0       3  female   NaN      8      2   69.5500        S  Third
# 867         0       1    male  31.0      0      0   50.4958        S  First
# 871         1       1  female  47.0      1      1   52.5542        S  First
# 879         1       1  female  56.0      0      1   83.1583        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 3    woman       False    C  Southampton   yes  False
# 6      man        True    E  Southampton    no   True
# 27     man        True    C  Southampton    no  False
# 31   woman       False    B    Cherbourg   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 856  woman       False  NaN  Southampton   yes  False
# 863  woman       False  NaN  Southampton    no  False
# 867    man        True    A  Southampton    no   True
# 871  woman       False    D  Southampton   yes  False
# 879  woman       False    C    Cherbourg   yes  False
#
# [160 rows x 15 columns]

# %%
#15. Count total male and female passengers.
df["sex"].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
#16. Count passengers in each passenger class.
df["pclass"].value_counts()
# Out:
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
#17. Find average age of passengers.
df["age"].mean()
# Out:
# np.float64(29.69911764705882)

# %%
#18. Find maximum fare paid.
df["fare"].max()
# Out:
# np.float64(512.3292)

# %%
#19. Find minimum fare paid.
df["fare"].min()
# Out:
# np.float64(0.0)

# %%
#20. Find total number of survived passengers.
df["survived"].sum()
# Out:
# np.int64(342)

# %%
df["survived"].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# ## Filtering and Conditional Selection (21–35)

# %%
#21. Show passengers with age less than 18.
df[df["age"]<18]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 14          0       3  female  14.0      0      0   7.8542        S   Third
# 16          0       3    male   2.0      4      1  29.1250        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 850         0       3    male   4.0      4      2  31.2750        S   Third
# 852         0       3  female   9.0      1      1  15.2458        C   Third
# 853         1       1  female  16.0      0      1  39.4000        S   First
# 869         1       3    male   4.0      1      1  11.1333        S   Third
# 875         1       3  female  15.0      0      0   7.2250        C   Third
#
#        who  adult_male deck  embark_town alive  alone
# 7    child       False  NaN  Southampton    no  False
# 9    child       False  NaN    Cherbourg   yes  False
# 10   child       False    G  Southampton   yes  False
# 14   child       False  NaN  Southampton    no   True
# 16   child       False  NaN   Queenstown    no  False
# ..     ...         ...  ...          ...   ...    ...
# 850  child       False  NaN  Southampton    no  False
# 852  child       False  NaN    Cherbourg    no  False
# 853  woman       False    D  Southampton   yes  False
# 869  child       False  NaN  Southampton   yes  False
# 875  child       False  NaN    Cherbourg   yes   True
#
# [113 rows x 15 columns]

# %%
#22. Show passengers who survived.
df[df["survived"]==1]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 8    woman       False  NaN  Southampton   yes  False
# 9    child       False  NaN    Cherbourg   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 875  child       False  NaN    Cherbourg   yes   True
# 879  woman       False    C    Cherbourg   yes  False
# 880  woman       False  NaN  Southampton   yes  False
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [342 rows x 15 columns]

# %%
#23. Show passengers who did not survive.
df[df["survived"]==0]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 4      man        True  NaN  Southampton    no   True
# 5      man        True  NaN   Queenstown    no   True
# 6      man        True    E  Southampton    no   True
# 7    child       False  NaN  Southampton    no  False
# ..     ...         ...  ...          ...   ...    ...
# 884    man        True  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 886    man        True  NaN  Southampton    no   True
# 888  woman       False  NaN  Southampton    no  False
# 890    man        True  NaN   Queenstown    no   True
#
# [549 rows x 15 columns]

# %%
#24. Show female passengers who survived.
df[(df["survived"]==1)&(df["sex"]=="female")]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 8    woman       False  NaN  Southampton   yes  False
# 9    child       False  NaN    Cherbourg   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 874  woman       False  NaN    Cherbourg   yes  False
# 875  child       False  NaN    Cherbourg   yes   True
# 879  woman       False    C    Cherbourg   yes  False
# 880  woman       False  NaN  Southampton   yes  False
# 887  woman       False    B  Southampton   yes   True
#
# [233 rows x 15 columns]

# %%
#25. Show male passengers who did not survive.
df[(df["survived"]==0)&(df["sex"]=="male")]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 881         0       3  male  33.0      0      0   7.8958        S   Third
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 4      man        True  NaN  Southampton    no   True
# 5      man        True  NaN   Queenstown    no   True
# 6      man        True    E  Southampton    no   True
# 7    child       False  NaN  Southampton    no  False
# ..     ...         ...  ...          ...   ...    ...
# 881    man        True  NaN  Southampton    no   True
# 883    man        True  NaN  Southampton    no   True
# 884    man        True  NaN  Southampton    no   True
# 886    man        True  NaN  Southampton    no   True
# 890    man        True  NaN   Queenstown    no   True
#
# [468 rows x 15 columns]

# %%
#26. Show passengers from class 1 who survived.
df[(df["survived"]==1)&(df["pclass"]==1)]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1           1       1  female  38.0      1      0   71.2833        C  First
# 3           1       1  female  35.0      1      0   53.1000        S  First
# 11          1       1  female  58.0      0      0   26.5500        S  First
# 23          1       1    male  28.0      0      0   35.5000        S  First
# 31          1       1  female   NaN      1      0  146.5208        C  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 862         1       1  female  48.0      0      0   25.9292        S  First
# 871         1       1  female  47.0      1      1   52.5542        S  First
# 879         1       1  female  56.0      0      1   83.1583        C  First
# 887         1       1  female  19.0      0      0   30.0000        S  First
# 889         1       1    male  26.0      0      0   30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 3    woman       False    C  Southampton   yes  False
# 11   woman       False    C  Southampton   yes   True
# 23     man        True    A  Southampton   yes   True
# 31   woman       False    B    Cherbourg   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 862  woman       False    D  Southampton   yes   True
# 871  woman       False    D  Southampton   yes  False
# 879  woman       False    C    Cherbourg   yes  False
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [136 rows x 15 columns]

# %%
#27. Show passengers whose fare is between 20 and 100.
df[(20<df["fare"]) & (df["fare"]<100)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 3    woman       False    C  Southampton   yes  False
# 6      man        True    E  Southampton    no   True
# 7    child       False  NaN  Southampton    no  False
# 9    child       False  NaN    Cherbourg   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 880  woman       False  NaN  Southampton   yes  False
# 885  woman       False  NaN   Queenstown    no  False
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
#
# [323 rows x 15 columns]

# %%
#28. Show passengers embarking from `S`.
df[df["embarked"]=="S"]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# 6      man        True    E  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 883    man        True  NaN  Southampton    no   True
# 884    man        True  NaN  Southampton    no   True
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
#
# [644 rows x 15 columns]

# %%
#29. Show passengers with missing age.
df[df["age"].isna()]
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 5           0       3    male  NaN      0      0   8.4583        Q   Third
# 17          1       2    male  NaN      0      0  13.0000        S  Second
# 19          1       3  female  NaN      0      0   7.2250        C   Third
# 26          0       3    male  NaN      0      0   7.2250        C   Third
# 28          1       3  female  NaN      0      0   7.8792        Q   Third
# ..        ...     ...     ...  ...    ...    ...      ...      ...     ...
# 859         0       3    male  NaN      0      0   7.2292        C   Third
# 863         0       3  female  NaN      8      2  69.5500        S   Third
# 868         0       3    male  NaN      0      0   9.5000        S   Third
# 878         0       3    male  NaN      0      0   7.8958        S   Third
# 888         0       3  female  NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 5      man        True  NaN   Queenstown    no   True
# 17     man        True  NaN  Southampton   yes   True
# 19   woman       False  NaN    Cherbourg   yes   True
# 26     man        True  NaN    Cherbourg    no   True
# 28   woman       False  NaN   Queenstown   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 859    man        True  NaN    Cherbourg    no   True
# 863  woman       False  NaN  Southampton    no  False
# 868    man        True  NaN  Southampton    no   True
# 878    man        True  NaN  Southampton    no   True
# 888  woman       False  NaN  Southampton    no  False
#
# [177 rows x 15 columns]

# %%
#30. Show passengers with known cabin details.

# %%
#31. Show passengers older than 60.
df[df["age"]>60].head()
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 33          0       2  male  66.0      0      0  10.5000        S  Second
# 54          0       1  male  65.0      0      1  61.9792        C   First
# 96          0       1  male  71.0      0      0  34.6542        C   First
# 116         0       3  male  70.5      0      0   7.7500        Q   Third
# 170         0       1  male  61.0      0      0  33.5000        S   First
#
#      who  adult_male deck  embark_town alive  alone
# 33   man        True  NaN  Southampton    no   True
# 54   man        True    B    Cherbourg    no  False
# 96   man        True    A    Cherbourg    no   True
# 116  man        True  NaN   Queenstown    no   True
# 170  man        True    B  Southampton    no   True

# %%
#32. Show passengers traveling alone (`SibSp = 0` and `Parch = 0`).
df[(df["sibsp"]==0)&(df["parch"]==0)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 11          1       1  female  58.0      0      0  26.5500        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 2    woman       False  NaN  Southampton   yes   True
# 4      man        True  NaN  Southampton    no   True
# 5      man        True  NaN   Queenstown    no   True
# 6      man        True    E  Southampton    no   True
# 11   woman       False    C  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 884    man        True  NaN  Southampton    no   True
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [537 rows x 15 columns]

# %%
#33. Show children traveling with parents.
df[df["parch"]==1]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# 16          0       3    male   2.0      4      1   29.1250        Q   Third
# 24          0       3  female   8.0      3      1   21.0750        S   Third
# 50          0       3    male   7.0      4      1   39.6875        S   Third
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 856         1       1  female  45.0      1      1  164.8667        S   First
# 869         1       3    male   4.0      1      1   11.1333        S   Third
# 871         1       1  female  47.0      1      1   52.5542        S   First
# 879         1       1  female  56.0      0      1   83.1583        C   First
# 880         1       2  female  25.0      0      1   26.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 7    child       False  NaN  Southampton    no  False
# 10   child       False    G  Southampton   yes  False
# 16   child       False  NaN   Queenstown    no  False
# 24   child       False  NaN  Southampton    no  False
# 50   child       False  NaN  Southampton    no  False
# ..     ...         ...  ...          ...   ...    ...
# 856  woman       False  NaN  Southampton   yes  False
# 869  child       False  NaN  Southampton   yes  False
# 871  woman       False    D  Southampton   yes  False
# 879  woman       False    C    Cherbourg   yes  False
# 880  woman       False  NaN  Southampton   yes  False
#
# [118 rows x 15 columns]

# %%
#34. Show passengers with titles containing “Mr”.

# %%
#35. Show passengers with names starting with “A”.

# %% [markdown]
# ## Sorting and Indexing (36–45)

# %%
#36. Sort passengers by age ascending.
df.sort_values(by="age").dropna()
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 305         1       1    male   0.92      1      2  151.5500        S   First
# 183         1       2    male   1.00      2      1   39.0000        S  Second
# 205         0       3  female   2.00      0      1   10.4625        S   Third
# 340         1       2    male   2.00      1      1   26.0000        S  Second
# 297         0       1  female   2.00      1      2  151.5500        S   First
# ..        ...     ...     ...    ...    ...    ...       ...      ...     ...
# 54          0       1    male  65.00      0      1   61.9792        C   First
# 456         0       1    male  65.00      0      0   26.5500        S   First
# 745         0       1    male  70.00      1      1   71.0000        S   First
# 96          0       1    male  71.00      0      0   34.6542        C   First
# 630         1       1    male  80.00      0      0   30.0000        S   First
#
#        who  adult_male deck  embark_town alive  alone
# 305  child       False    C  Southampton   yes  False
# 183  child       False    F  Southampton   yes  False
# 205  child       False    G  Southampton    no  False
# 340  child       False    F  Southampton   yes  False
# 297  child       False    C  Southampton    no  False
# ..     ...         ...  ...          ...   ...    ...
# 54     man        True    B    Cherbourg    no  False
# 456    man        True    E  Southampton    no   True
# 745    man        True    B  Southampton    no  False
# 96     man        True    A    Cherbourg    no   True
# 630    man        True    A  Southampton   yes   True
#
# [182 rows x 15 columns]

# %%
#37. Sort passengers by fare descending.
df.sort_values(by="fare", ascending=False).dropna()
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 88          1       1  female  23.0      3      2  263.0000        S  First
# 438         0       1    male  64.0      1      4  263.0000        S  First
# 341         1       1  female  24.0      3      2  263.0000        S  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 699         0       3    male  42.0      0      0    7.6500        S  Third
# 715         0       3    male  19.0      0      0    7.6500        S  Third
# 872         0       1    male  33.0      0      0    5.0000        S  First
# 263         0       1    male  40.0      0      0    0.0000        S  First
# 806         0       1    male  39.0      0      0    0.0000        S  First
#
#        who  adult_male deck  embark_town alive  alone
# 679    man        True    B    Cherbourg   yes  False
# 737    man        True    B    Cherbourg   yes   True
# 88   woman       False    C  Southampton   yes  False
# 438    man        True    C  Southampton    no  False
# 341  woman       False    C  Southampton   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 699    man        True    F  Southampton    no   True
# 715    man        True    F  Southampton    no   True
# 872    man        True    B  Southampton    no   True
# 263    man        True    B  Southampton    no   True
# 806    man        True    A  Southampton    no   True
#
# [182 rows x 15 columns]

# %%
#38. Sort by class and then age.
df.sort_values(by=["class","age"])
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked  class  \
# 305         1       1    male   0.92      1      2  151.5500        S  First
# 297         0       1  female   2.00      1      2  151.5500        S  First
# 445         1       1    male   4.00      0      2   81.8583        S  First
# 802         1       1    male  11.00      1      2  120.0000        S  First
# 435         1       1  female  14.00      1      2  120.0000        S  First
# ..        ...     ...     ...    ...    ...    ...       ...      ...    ...
# 859         0       3    male    NaN      0      0    7.2292        C  Third
# 863         0       3  female    NaN      8      2   69.5500        S  Third
# 868         0       3    male    NaN      0      0    9.5000        S  Third
# 878         0       3    male    NaN      0      0    7.8958        S  Third
# 888         0       3  female    NaN      1      2   23.4500        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 305  child       False    C  Southampton   yes  False
# 297  child       False    C  Southampton    no  False
# 445  child       False    A  Southampton   yes  False
# 802  child       False    B  Southampton   yes  False
# 435  child       False    B  Southampton   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 859    man        True  NaN    Cherbourg    no   True
# 863  woman       False  NaN  Southampton    no  False
# 868    man        True  NaN  Southampton    no   True
# 878    man        True  NaN  Southampton    no   True
# 888  woman       False  NaN  Southampton    no  False
#
# [891 rows x 15 columns]

# %%
#39. Set `survived` as index.
df1=df.set_index("survived")
df1
# Out:
#           pclass     sex        age  sibsp  parch     fare embarked   class  \
# survived
# 0              3    male  22.000000      1      0   7.2500        S   Third
# 1              1  female  38.000000      1      0  71.2833        C   First
# 1              3  female  26.000000      0      0   7.9250        S   Third
# 1              1  female  35.000000      1      0  53.1000        S   First
# 0              3    male  35.000000      0      0   8.0500        S   Third
# ...          ...     ...        ...    ...    ...      ...      ...     ...
# 0              2    male  27.000000      0      0  13.0000        S  Second
# 1              1  female  19.000000      0      0  30.0000        S   First
# 0              3  female  29.699118      1      2  23.4500        S   Third
# 1              1    male  26.000000      0      0  30.0000        C   First
# 0              3    male  32.000000      0      0   7.7500        Q   Third
#
#             who  adult_male deck  embark_town alive  alone
# survived
# 0           man        True  NaN  Southampton    no  False
# 1         woman       False    C    Cherbourg   yes  False
# 1         woman       False  NaN  Southampton   yes   True
# 1         woman       False    C  Southampton   yes  False
# 0           man        True  NaN  Southampton    no   True
# ...         ...         ...  ...          ...   ...    ...
# 0           man        True  NaN  Southampton    no   True
# 1         woman       False    B  Southampton   yes   True
# 0         woman       False  NaN  Southampton    no  False
# 1           man        True    C    Cherbourg   yes   True
# 0           man        True  NaN   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
#40. Reset the index.
df1.reset_index()
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# 0     Third    man        True  NaN  Southampton    no  False
# 1     First  woman       False    C    Cherbourg   yes  False
# 2     Third  woman       False  NaN  Southampton   yes   True
# 3     First  woman       False    C  Southampton   yes  False
# 4     Third    man        True  NaN  Southampton    no   True
# ..      ...    ...         ...  ...          ...   ...    ...
# 886  Second    man        True  NaN  Southampton    no   True
# 887   First  woman       False    B  Southampton   yes   True
# 888   Third  woman       False  NaN  Southampton    no  False
# 889   First    man        True    C    Cherbourg   yes   True
# 890   Third    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
#41. Display row with index 10 using `.loc`.
print(df.loc[10])
# Out:
# survived                 1
# pclass                   3
# sex                 female
# age                    4.0
# sibsp                    1
# parch                    1
# fare                  16.7
# embarked                 S
# class                Third
# who                  child
# adult_male           False
# deck                     G
# embark_town    Southampton
# alive                  yes
# alone                False
# Name: 10, dtype: object

# %%
#42. Display row with position 10 using `.iloc`.
df.iloc[10]
# Out:
# survived                 1
# pclass                   3
# sex                 female
# age                    4.0
# sibsp                    1
# parch                    1
# fare                  16.7
# embarked                 S
# class                Third
# who                  child
# adult_male           False
# deck                     G
# embark_town    Southampton
# alive                  yes
# alone                False
# Name: 10, dtype: object

# %%
#43. Display first 5 rows and first 3 columns.
df.iloc[:5,:3]
# Out:
#    survived  pclass     sex
# 0         0       3    male
# 1         1       1  female
# 2         1       3  female
# 3         1       1  female
# 4         0       3    male

# %%
#44. Select only rows 10–20.
df.iloc[10:21]
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 12         0       3    male  20.0      0      0   8.0500        S   Third
# 13         0       3    male  39.0      1      5  31.2750        S   Third
# 14         0       3  female  14.0      0      0   7.8542        S   Third
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 16         0       3    male   2.0      4      1  29.1250        Q   Third
# 17         1       2    male   NaN      0      0  13.0000        S  Second
# 18         0       3  female  31.0      1      0  18.0000        S   Third
# 19         1       3  female   NaN      0      0   7.2250        C   Third
# 20         0       2    male  35.0      0      0  26.0000        S  Second
#
#       who  adult_male deck  embark_town alive  alone
# 10  child       False    G  Southampton   yes  False
# 11  woman       False    C  Southampton   yes   True
# 12    man        True  NaN  Southampton    no   True
# 13    man        True  NaN  Southampton    no  False
# 14  child       False  NaN  Southampton    no   True
# 15  woman       False  NaN  Southampton   yes   True
# 16  child       False  NaN   Queenstown    no  False
# 17    man        True  NaN  Southampton   yes   True
# 18  woman       False  NaN  Southampton    no  False
# 19  woman       False  NaN    Cherbourg   yes   True
# 20    man        True  NaN  Southampton    no   True

# %%
#45. Select `Name` and `Fare` for first 10 passengers.
df[["sex", "fare"]].head(10)
# Out:
#       sex     fare
# 0    male   7.2500
# 1  female  71.2833
# 2  female   7.9250
# 3  female  53.1000
# 4    male   8.0500
# 5    male   8.4583
# 6    male  51.8625
# 7    male  21.0750
# 8  female  11.1333
# 9  female  30.0708

# %% [markdown]
# ## Missing Value Handling (46–55)

# %%
#46. Count missing values in `Age`.
df["age"].isna().value_counts()
# Out:
# age
# False    714
# True     177
# Name: count, dtype: int64

# %%
df["age"].isna().sum()
# Out:
# np.int64(177)

# %%
#47. Count missing values in `Cabin`.

# %%
#48. Fill missing age with mean age.
df1["age"]=df["age"].fillna(df["age"].mean())
df1
# Out:
#           pclass     sex   age  sibsp  parch     fare embarked   class    who  \
# survived
# 0              3    male  22.0      1      0   7.2500        S   Third    man
# 1              1  female  38.0      1      0  71.2833        C   First  woman
# 1              3  female  38.0      0      0   7.9250        S   Third  woman
# 1              1  female  38.0      1      0  53.1000        S   First  woman
# 0              3    male  22.0      0      0   8.0500        S   Third    man
# ...          ...     ...   ...    ...    ...      ...      ...     ...    ...
# 0              2    male  22.0      0      0  13.0000        S  Second    man
# 1              1  female  38.0      0      0  30.0000        S   First  woman
# 0              3  female  22.0      1      2  23.4500        S   Third  woman
# 1              1    male  38.0      0      0  30.0000        C   First    man
# 0              3    male  22.0      0      0   7.7500        Q   Third    man
#
#           adult_male deck  embark_town alive  alone
# survived
# 0               True  NaN  Southampton    no  False
# 1              False    C    Cherbourg   yes  False
# 1              False  NaN  Southampton   yes   True
# 1              False    C  Southampton   yes  False
# 0               True  NaN  Southampton    no   True
# ...              ...  ...          ...   ...    ...
# 0               True  NaN  Southampton    no   True
# 1              False    B  Southampton   yes   True
# 0              False  NaN  Southampton    no  False
# 1               True    C    Cherbourg   yes   True
# 0               True  NaN   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
#49. Fill missing age with median age.
df1["age"]=df["age"].fillna(df["age"].median())
df1
# Out:
#           pclass     sex   age  sibsp  parch     fare embarked   class    who  \
# survived
# 0              3    male  22.0      1      0   7.2500        S   Third    man
# 1              1  female  38.0      1      0  71.2833        C   First  woman
# 1              3  female  38.0      0      0   7.9250        S   Third  woman
# 1              1  female  38.0      1      0  53.1000        S   First  woman
# 0              3    male  22.0      0      0   8.0500        S   Third    man
# ...          ...     ...   ...    ...    ...      ...      ...     ...    ...
# 0              2    male  22.0      0      0  13.0000        S  Second    man
# 1              1  female  38.0      0      0  30.0000        S   First  woman
# 0              3  female  22.0      1      2  23.4500        S   Third  woman
# 1              1    male  38.0      0      0  30.0000        C   First    man
# 0              3    male  22.0      0      0   7.7500        Q   Third    man
#
#           adult_male deck  embark_town alive  alone
# survived
# 0               True  NaN  Southampton    no  False
# 1              False    C    Cherbourg   yes  False
# 1              False  NaN  Southampton   yes   True
# 1              False    C  Southampton   yes  False
# 0               True  NaN  Southampton    no   True
# ...              ...  ...          ...   ...    ...
# 0               True  NaN  Southampton    no   True
# 1              False    B  Southampton   yes   True
# 0              False  NaN  Southampton    no  False
# 1               True    C    Cherbourg   yes   True
# 0               True  NaN   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
#50. Fill missing `Embarked` with mode.
df1["embarked"]=df["embarked"].fillna(df["embarked"].mode())
df1
# Out:
#           pclass     sex   age  sibsp  parch     fare embarked   class    who  \
# survived
# 0              3    male  22.0      1      0   7.2500        S   Third    man
# 1              1  female  38.0      1      0  71.2833        C   First  woman
# 1              3  female  38.0      0      0   7.9250        C   Third  woman
# 1              1  female  38.0      1      0  53.1000        C   First  woman
# 0              3    male  22.0      0      0   8.0500        S   Third    man
# ...          ...     ...   ...    ...    ...      ...      ...     ...    ...
# 0              2    male  22.0      0      0  13.0000        S  Second    man
# 1              1  female  38.0      0      0  30.0000        C   First  woman
# 0              3  female  22.0      1      2  23.4500        S   Third  woman
# 1              1    male  38.0      0      0  30.0000        C   First    man
# 0              3    male  22.0      0      0   7.7500        S   Third    man
#
#           adult_male deck  embark_town alive  alone
# survived
# 0               True  NaN  Southampton    no  False
# 1              False    C    Cherbourg   yes  False
# 1              False  NaN  Southampton   yes   True
# 1              False    C  Southampton   yes  False
# 0               True  NaN  Southampton    no   True
# ...              ...  ...          ...   ...    ...
# 0               True  NaN  Southampton    no   True
# 1              False    B  Southampton   yes   True
# 0              False  NaN  Southampton    no  False
# 1               True    C    Cherbourg   yes   True
# 0               True  NaN   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
#51. Drop rows with missing age.
df["age"].dropna()
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: age, Length: 714, dtype: float64

# %%
#52. Drop rows with any missing value.
df.dropna(how="any")
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 3    woman       False    C  Southampton   yes  False
# 6      man        True    E  Southampton    no   True
# 10   child       False    G  Southampton   yes  False
# 11   woman       False    C  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 871  woman       False    D  Southampton   yes  False
# 872    man        True    B  Southampton    no   True
# 879  woman       False    C    Cherbourg   yes  False
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [182 rows x 15 columns]

# %%
#53. Replace missing cabin values with `"Unknown"`.

# %%
#54. Check null values using `isnull()`.
df.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# 0    False       False   True        False  False  False
# 1    False       False  False        False  False  False
# 2    False       False   True        False  False  False
# 3    False       False  False        False  False  False
# 4    False       False   True        False  False  False
# ..     ...         ...    ...          ...    ...    ...
# 886  False       False   True        False  False  False
# 887  False       False  False        False  False  False
# 888  False       False   True        False  False  False
# 889  False       False  False        False  False  False
# 890  False       False   True        False  False  False
#
# [891 rows x 15 columns]

# %%
#55. Check non-null values using `notnull()`.
df.notnull()
# Out:
#      survived  pclass   sex    age  sibsp  parch  fare  embarked  class   who  \
# 0        True    True  True   True   True   True  True      True   True  True
# 1        True    True  True   True   True   True  True      True   True  True
# 2        True    True  True   True   True   True  True      True   True  True
# 3        True    True  True   True   True   True  True      True   True  True
# 4        True    True  True   True   True   True  True      True   True  True
# ..        ...     ...   ...    ...    ...    ...   ...       ...    ...   ...
# 886      True    True  True   True   True   True  True      True   True  True
# 887      True    True  True   True   True   True  True      True   True  True
# 888      True    True  True  False   True   True  True      True   True  True
# 889      True    True  True   True   True   True  True      True   True  True
# 890      True    True  True   True   True   True  True      True   True  True
#
#      adult_male   deck  embark_town  alive  alone
# 0          True  False         True   True   True
# 1          True   True         True   True   True
# 2          True  False         True   True   True
# 3          True   True         True   True   True
# 4          True  False         True   True   True
# ..          ...    ...          ...    ...    ...
# 886        True  False         True   True   True
# 887        True   True         True   True   True
# 888        True  False         True   True   True
# 889        True   True         True   True   True
# 890        True  False         True   True   True
#
# [891 rows x 15 columns]

# %% [markdown]
# ## GroupBy Questions (56–65)

# %%
#56. Find average age by gender.
df.groupby("sex")["age"].mean()
# Out:
# sex
# female    27.915709
# male      30.726645
# Name: age, dtype: float64

# %%
#57. Find average fare by class.
df.groupby("class")["fare"].mean()
# Out:
# class
# First     84.154687
# Second    20.662183
# Third     13.675550
# Name: fare, dtype: float64

# %%
#58. Find survival count by gender.
df.groupby("sex")["survived"].value_counts()
# Out:
# sex     survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: count, dtype: int64

# %%
#59. Find survival count by class.
df.groupby("class")["survived"].value_counts()
# Out:
# class   survived
# First   1           136
#         0            80
# Second  0            97
#         1            87
# Third   0           372
#         1           119
# Name: count, dtype: int64

# %%
#60. Find average age by class.
df.groupby("class")["age"].mean()
# Out:
# class
# First     38.233441
# Second    29.877630
# Third     25.140620
# Name: age, dtype: float64

# %%
#61. Find average fare by embarkation point.
df.groupby("embark_town")["fare"].mean()
# Out:
# embark_town
# Cherbourg      59.954144
# Queenstown     13.276030
# Southampton    27.079812
# Name: fare, dtype: float64

# %%
#62. Find maximum fare by class.
df.groupby("class")["fare"].max()
# Out:
# class
# First     512.3292
# Second     73.5000
# Third      69.5500
# Name: fare, dtype: float64

# %%
#63. Find minimum age by class.
df.groupby("class")["age"].min()
# Out:
# class
# First     0.92
# Second    0.67
# Third     0.42
# Name: age, dtype: float64

# %%
#64. Find count of passengers by gender and class.
df.groupby(["sex","class"]).size()
# Out:
# sex     class
# female  First      94
#         Second     76
#         Third     144
# male    First     122
#         Second    108
#         Third     347
# dtype: int64

# %%
#65. Find survival percentage by class.
df.groupby("class")["survived"].mean()*100
# Out:
# class
# First     62.962963
# Second    47.282609
# Third     24.236253
# Name: survived, dtype: float64

# %% [markdown]
# ## Feature Engineering (66–75)

# %%
#66. Create a new column `FamilySize = SibSp + Parch`.
df["Familysize"]=df["sibsp"]+df["parch"]
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Familysize
# 0      man        True  NaN  Southampton    no  False           1
# 1    woman       False    C    Cherbourg   yes  False           1
# 2    woman       False  NaN  Southampton   yes   True           0
# 3    woman       False    C  Southampton   yes  False           1
# 4      man        True  NaN  Southampton    no   True           0
# ..     ...         ...  ...          ...   ...    ...         ...
# 886    man        True  NaN  Southampton    no   True           0
# 887  woman       False    B  Southampton   yes   True           0
# 888  woman       False  NaN  Southampton    no  False           3
# 889    man        True    C    Cherbourg   yes   True           0
# 890    man        True  NaN   Queenstown    no   True           0
#
# [891 rows x 16 columns]

# %%
#67. Create a new column `IsAlone`.
df["Isalone"]=((df["sibsp"]==0) & (df["parch"]==0)).astype(int)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Familysize  Isalone
# 0      man        True  NaN  Southampton    no  False           1        0
# 1    woman       False    C    Cherbourg   yes  False           1        0
# 2    woman       False  NaN  Southampton   yes   True           0        1
# 3    woman       False    C  Southampton   yes  False           1        0
# 4      man        True  NaN  Southampton    no   True           0        1
# ..     ...         ...  ...          ...   ...    ...         ...      ...
# 886    man        True  NaN  Southampton    no   True           0        1
# 887  woman       False    B  Southampton   yes   True           0        1
# 888  woman       False  NaN  Southampton    no  False           3        0
# 889    man        True    C    Cherbourg   yes   True           0        1
# 890    man        True  NaN   Queenstown    no   True           0        1
#
# [891 rows x 17 columns]

# %%
#68. Create age groups: child, adult, senior.
df["age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64

# %%
bins = [0, 18, 60, 100]
labels = ['Child', 'Adult', 'Senior']

# Create the new column
df['AgeGroup'] = pd.cut(df['age'], bins=bins, labels=labels, right=False)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Familysize  Isalone  \
# 0      man        True  NaN  Southampton    no  False           1        0
# 1    woman       False    C    Cherbourg   yes  False           1        0
# 2    woman       False  NaN  Southampton   yes   True           0        1
# 3    woman       False    C  Southampton   yes  False           1        0
# 4      man        True  NaN  Southampton    no   True           0        1
# ..     ...         ...  ...          ...   ...    ...         ...      ...
# 886    man        True  NaN  Southampton    no   True           0        1
# 887  woman       False    B  Southampton   yes   True           0        1
# 888  woman       False  NaN  Southampton    no  False           3        0
# 889    man        True    C    Cherbourg   yes   True           0        1
# 890    man        True  NaN   Queenstown    no   True           0        1
#
#     AgeGroup
# 0      Adult
# 1      Adult
# 2      Adult
# 3      Adult
# 4      Adult
# ..       ...
# 886    Adult
# 887    Adult
# 888      NaN
# 889    Adult
# 890    Adult
#
# [891 rows x 18 columns]

# %%
#70. Extract title from passenger names.

# %%
#69. Create fare categories: low, medium, high.
bins=[0,15,35,550]
labels=["Low","Medium","High"]
df["FareCategory"]=pd.cut(df["age"], bins=bins, labels=labels)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Familysize  Isalone  \
# 0      man        True  NaN  Southampton    no  False           1        0
# 1    woman       False    C    Cherbourg   yes  False           1        0
# 2    woman       False  NaN  Southampton   yes   True           0        1
# 3    woman       False    C  Southampton   yes  False           1        0
# 4      man        True  NaN  Southampton    no   True           0        1
# ..     ...         ...  ...          ...   ...    ...         ...      ...
# 886    man        True  NaN  Southampton    no   True           0        1
# 887  woman       False    B  Southampton   yes   True           0        1
# 888  woman       False  NaN  Southampton    no  False           3        0
# 889    man        True    C    Cherbourg   yes   True           0        1
# 890    man        True  NaN   Queenstown    no   True           0        1
#
#     AgeGroup FareCategory
# 0      Adult       Medium
# 1      Adult         High
# 2      Adult       Medium
# 3      Adult       Medium
# 4      Adult       Medium
# ..       ...          ...
# 886    Adult       Medium
# 887    Adult       Medium
# 888      NaN          NaN
# 889    Adult       Medium
# 890    Adult       Medium
#
# [891 rows x 19 columns]

# %%
df['fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64

# %%
#71. Create a column for surname.

# %%
#72. Create a column `Fare_per_person`.
# 1. Calculate the total family size (including the passenger)
df['FamilySize'] = df['sibsp'] + df['parch'] + 1

# 2. Divide the total fare by the family size
df['Fare_per_person'] = df['fare'] / df['FamilySize']
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  ...  deck  embark_town alive  alone  Familysize  Isalone  \
# 0      man  ...   NaN  Southampton    no  False           1        0
# 1    woman  ...     C    Cherbourg   yes  False           1        0
# 2    woman  ...   NaN  Southampton   yes   True           0        1
# 3    woman  ...     C  Southampton   yes  False           1        0
# 4      man  ...   NaN  Southampton    no   True           0        1
# ..     ...  ...   ...          ...   ...    ...         ...      ...
# 886    man  ...   NaN  Southampton    no   True           0        1
# 887  woman  ...     B  Southampton   yes   True           0        1
# 888  woman  ...   NaN  Southampton    no  False           3        0
# 889    man  ...     C    Cherbourg   yes   True           0        1
# 890    man  ...   NaN   Queenstown    no   True           0        1
#
#      AgeGroup FareCategory FamilySize  Fare_per_person
# 0       Adult       Medium          2          3.62500
# 1       Adult         High          2         35.64165
# 2       Adult       Medium          1          7.92500
# 3       Adult       Medium          2         26.55000
# 4       Adult       Medium          1          8.05000
# ..        ...          ...        ...              ...
# 886     Adult       Medium          1         13.00000
# 887     Adult       Medium          1         30.00000
# 888       NaN          NaN          4          5.86250
# 889     Adult       Medium          1         30.00000
# 890     Adult       Medium          1          7.75000
#
# [891 rows x 21 columns]

# %%
#73. Convert `Sex` into numeric values.
gender_map = {'male': 0, 'female': 1}

# Apply the map to the Sex column
df['sex'] = df['sex'].map(gender_map)
df
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    0  22.0      1      0   7.2500        S   Third
# 1           1       1    1  38.0      1      0  71.2833        C   First
# 2           1       3    1  26.0      0      0   7.9250        S   Third
# 3           1       1    1  35.0      1      0  53.1000        S   First
# 4           0       3    0  35.0      0      0   8.0500        S   Third
# ..        ...     ...  ...   ...    ...    ...      ...      ...     ...
# 886         0       2    0  27.0      0      0  13.0000        S  Second
# 887         1       1    1  19.0      0      0  30.0000        S   First
# 888         0       3    1   NaN      1      2  23.4500        S   Third
# 889         1       1    0  26.0      0      0  30.0000        C   First
# 890         0       3    0  32.0      0      0   7.7500        Q   Third
#
#        who  ...  deck  embark_town alive  alone  Familysize  Isalone  \
# 0      man  ...   NaN  Southampton    no  False           1        0
# 1    woman  ...     C    Cherbourg   yes  False           1        0
# 2    woman  ...   NaN  Southampton   yes   True           0        1
# 3    woman  ...     C  Southampton   yes  False           1        0
# 4      man  ...   NaN  Southampton    no   True           0        1
# ..     ...  ...   ...          ...   ...    ...         ...      ...
# 886    man  ...   NaN  Southampton    no   True           0        1
# 887  woman  ...     B  Southampton   yes   True           0        1
# 888  woman  ...   NaN  Southampton    no  False           3        0
# 889    man  ...     C    Cherbourg   yes   True           0        1
# 890    man  ...   NaN   Queenstown    no   True           0        1
#
#      AgeGroup FareCategory FamilySize  Fare_per_person
# 0       Adult       Medium          2          3.62500
# 1       Adult         High          2         35.64165
# 2       Adult       Medium          1          7.92500
# 3       Adult       Medium          2         26.55000
# 4       Adult       Medium          1          8.05000
# ..        ...          ...        ...              ...
# 886     Adult       Medium          1         13.00000
# 887     Adult       Medium          1         30.00000
# 888       NaN          NaN          4          5.86250
# 889     Adult       Medium          1         30.00000
# 890     Adult       Medium          1          7.75000
#
# [891 rows x 21 columns]

# %%
#74. Convert survival values into labels `Yes/No`.
gender_map = {0: "Yes", 1: "No"}

# Apply the map to the Sex column
df['survived'] = df['survived'].map(gender_map)
df
# Out:
#     survived  pclass  sex   age  sibsp  parch     fare embarked   class  \
# 0        Yes       3    0  22.0      1      0   7.2500        S   Third
# 1         No       1    1  38.0      1      0  71.2833        C   First
# 2         No       3    1  26.0      0      0   7.9250        S   Third
# 3         No       1    1  35.0      1      0  53.1000        S   First
# 4        Yes       3    0  35.0      0      0   8.0500        S   Third
# ..       ...     ...  ...   ...    ...    ...      ...      ...     ...
# 886      Yes       2    0  27.0      0      0  13.0000        S  Second
# 887       No       1    1  19.0      0      0  30.0000        S   First
# 888      Yes       3    1   NaN      1      2  23.4500        S   Third
# 889       No       1    0  26.0      0      0  30.0000        C   First
# 890      Yes       3    0  32.0      0      0   7.7500        Q   Third
#
#        who  ...  deck  embark_town alive  alone  Familysize  Isalone  \
# 0      man  ...   NaN  Southampton    no  False           1        0
# 1    woman  ...     C    Cherbourg   yes  False           1        0
# 2    woman  ...   NaN  Southampton   yes   True           0        1
# 3    woman  ...     C  Southampton   yes  False           1        0
# 4      man  ...   NaN  Southampton    no   True           0        1
# ..     ...  ...   ...          ...   ...    ...         ...      ...
# 886    man  ...   NaN  Southampton    no   True           0        1
# 887  woman  ...     B  Southampton   yes   True           0        1
# 888  woman  ...   NaN  Southampton    no  False           3        0
# 889    man  ...     C    Cherbourg   yes   True           0        1
# 890    man  ...   NaN   Queenstown    no   True           0        1
#
#      AgeGroup FareCategory FamilySize  Fare_per_person
# 0       Adult       Medium          2          3.62500
# 1       Adult         High          2         35.64165
# 2       Adult       Medium          1          7.92500
# 3       Adult       Medium          2         26.55000
# 4       Adult       Medium          1          8.05000
# ..        ...          ...        ...              ...
# 886     Adult       Medium          1         13.00000
# 887     Adult       Medium          1         30.00000
# 888       NaN          NaN          4          5.86250
# 889     Adult       Medium          1         30.00000
# 890     Adult       Medium          1          7.75000
#
# [891 rows x 21 columns]

# %%
#75. Add a column showing age after 5 years.
df["Age_+5"]=df["age"]+5
df
# Out:
#     survived  pclass  sex   age  sibsp  parch     fare embarked   class  \
# 0        Yes       3    0  22.0      1      0   7.2500        S   Third
# 1         No       1    1  38.0      1      0  71.2833        C   First
# 2         No       3    1  26.0      0      0   7.9250        S   Third
# 3         No       1    1  35.0      1      0  53.1000        S   First
# 4        Yes       3    0  35.0      0      0   8.0500        S   Third
# ..       ...     ...  ...   ...    ...    ...      ...      ...     ...
# 886      Yes       2    0  27.0      0      0  13.0000        S  Second
# 887       No       1    1  19.0      0      0  30.0000        S   First
# 888      Yes       3    1   NaN      1      2  23.4500        S   Third
# 889       No       1    0  26.0      0      0  30.0000        C   First
# 890      Yes       3    0  32.0      0      0   7.7500        Q   Third
#
#        who  ...  embark_town alive  alone Familysize  Isalone  AgeGroup  \
# 0      man  ...  Southampton    no  False          1        0     Adult
# 1    woman  ...    Cherbourg   yes  False          1        0     Adult
# 2    woman  ...  Southampton   yes   True          0        1     Adult
# 3    woman  ...  Southampton   yes  False          1        0     Adult
# 4      man  ...  Southampton    no   True          0        1     Adult
# ..     ...  ...          ...   ...    ...        ...      ...       ...
# 886    man  ...  Southampton    no   True          0        1     Adult
# 887  woman  ...  Southampton   yes   True          0        1     Adult
# 888  woman  ...  Southampton    no  False          3        0       NaN
# 889    man  ...    Cherbourg   yes   True          0        1     Adult
# 890    man  ...   Queenstown    no   True          0        1     Adult
#
#      FareCategory FamilySize Fare_per_person  Age_+5
# 0          Medium          2         3.62500    27.0
# 1            High          2        35.64165    43.0
# 2          Medium          1         7.92500    31.0
# 3          Medium          2        26.55000    40.0
# 4          Medium          1         8.05000    40.0
# ..            ...        ...             ...     ...
# 886        Medium          1        13.00000    32.0
# 887        Medium          1        30.00000    24.0
# 888           NaN          4         5.86250     NaN
# 889        Medium          1        30.00000    31.0
# 890        Medium          1         7.75000    37.0
#
# [891 rows x 22 columns]
