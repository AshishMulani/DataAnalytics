# %%
import numpy as np

# %%
#step1:create array
arr=np.arange(55,65)
print("Original Array :\n",arr)
# Out:
# Original Array :
#  [55 56 57 58 59 60 61 62 63 64]

# %%
#step2:Apply condition(vectorized)
mask=arr>58
print("\nCondition (arr>58):",mask)
# Out:
# Condition (arr>58): [False False False False  True  True  True  True  True  True]

# %%
#step3:Apply Boolean mask
boolean_arrr=arr>58
boolean_arr
# Out:
# array([False, False, False, False,  True,  True,  True,  True,  True,
#         True])

# %%
#step4:Filter values
filtered=arr[mask]
print("\filtered values:",filtered)
# Out:
# iltered values: [59 60 61 62 63 64]

# %%
#direct filtering
print("Direct filtering (best practice):",arr[arr>58])
# Out:
# Direct filtering (best practice): [59 60 61 62 63 64]

# %%
#multiple conditions
print("\nValues between 57 and 62:",arr[(arr>57)&(arr<63)])
# Out:
# Values between 57 and 62: [58 59 60 61 62]

# %% [markdown]
# #### Example: Student Marks

# %%
import numpy as np
marks = np.array([67,32,89,56,34,36])
marks
# Out:
# array([67, 32, 89, 56, 34, 36])

# %%
passing_students_boolean = marks>35
print(passing_students_boolean)
# Out:
# [ True False  True  True False  True]

# %%
print(marks[passing_students_boolean])
# Out:
# [67 89 56 36]
